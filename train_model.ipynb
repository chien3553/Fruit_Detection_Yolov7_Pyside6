# %%
# %cd /content/drive/MyDrive/AI
# !git clone https://github.com/WongKinYiu/yolov7.git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/AI/yolov7
# !pip install -r requirements.txt

# %%
# !unzip /content/drive/MyDrive/Fruit.v2i.yolov7pytorch.zip -d /content/drive/MyDrive/AI

# %%
# %cd /content/drive/MyDrive/AI/yolov7
# !mkdir pretrain
# %cd pretrain
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt

# %%
# %cd /content/drive/MyDrive/AI/yolov7
# !python train.py --batch 8 --cfg cfg/training/yolov7.yaml --epochs 100 --data /content/drive/MyDrive/AI/data/data.yaml --weights 'pretrain/yolov7.pt'
# Out:
# /content/drive/MyDrive/AI/yolov7
# 2023-05-04 05:27:54.353360: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-04 05:27:55.262497: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 v0.1-122-g3b41c2c torch 2.0.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# ...
